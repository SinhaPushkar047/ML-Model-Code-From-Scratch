# %% [markdown]
# <a href="https://colab.research.google.com/github/SinhaPushkar047/ML-Model-Code-From-Scratch/blob/main/Perpectron_Trick.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import r2_score

# %% [markdown]
# # **Load Dataset**

# %%
from sklearn.datasets import load_diabetes
data=load_diabetes()


from sklearn.model_selection import train_test_split
x = data.data
y = data.target
x_train, x_test, y_train, y_test = train_test_split(
    x, y,
    test_size=0.2,
    random_state=42
)

# %% [markdown]
# # **Perceptron Trick**

# %%
class Perceptron_Trick:
  def __init__(self,lr=0.01,epoch=10000):
    self.lr=lr
    self.epoch=epoch
  def fit(self,x,y):
    x=np.insert(x,0,1,axis=1)
    self.w=np.ones(x.shape[1])
    for i in range(self.epoch):
      idx=np.random.randint(0,x.shape[0])
      self.w=self.w+self.lr*(y[idx]-x[idx].dot(self.w))*x[idx]
  def pred(self,x):
    x=np.insert(x,0,1,axis=1)
    return x.dot(self.w)

# %%
pt=Perceptron_Trick(lr=0.1)

# %%
pt.fit(x_train,y_train)

# %%
y_pred=pt.pred(x_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.4636086655226428
